# %%
import pandas as pd

# %%
df_bookings = pd.read_csv('bookings.csv')

# %%
df_bookings
# Out:
#       id|room|start date|end date|request id
# 0               1|L0|2016-02-07|2016-02-10|1
# 1               2|L0|2016-03-13|2016-03-21|2
# 2               3|D2|2016-02-19|2016-02-20|3
# 3               4|X0|2016-01-22|2016-01-26|4
# 4               5|L0|2016-02-22|2016-02-26|5
# 5               6|N0|2016-03-14|2016-03-25|6
# 6               7|N1|2016-03-14|2016-03-25|6
# 7               8|N2|2016-03-14|2016-03-25|6
# 8               9|N0|2016-01-22|2016-01-24|7
# 9              10|N1|2016-01-22|2016-01-24|7
# 10             11|N2|2016-01-22|2016-01-24|7
# 11             12|L6|2016-03-02|2016-03-03|8
# 12             13|D1|2016-02-01|2016-02-03|9
# 13           14|X23|2016-03-17|2016-03-20|10
# 14           15|X24|2016-03-17|2016-03-20|10
# 15            16|D0|2016-03-16|2016-03-19|11
# 16            17|D0|2016-02-02|2016-02-08|12
# 17            18|D4|2016-02-02|2016-02-08|12
# 18            19|L1|2016-02-07|2016-02-11|13
# 19           20|S11|2016-03-19|2016-03-21|14
# ...

# %%
df_food_orders = pd.read_csv('food-orders.csv')

# %%
df_menu = pd.read_csv('menu.csv')

# %%
df_requests = pd.read_csv('requests.csv')

# %%
df_room = pd.read_csv('rooms.csv')

# %%
df_room
# Out:
#   id|price/day|capacity|type|prefix
# 0             1|150|3|deluxe_room|X
# 1             2|100|3|double_room|D
# 2   3|80|15|conference_room_small|S
# 3              4|80|1|normal_room|N
# 4  5|150|50|conference_room_large|L

# %%
df_requests
# Out:
#       request id                 client name              room type  \
# 0              1             Dr. Iza Gerhold  conference_room_large
# 1              2                  Ila Sawayn  conference_room_large
# 2              3          Iverson McCullough            double_room
# 3              4        Katharyn Goyette DVM            deluxe_room
# 4              5          Deloris Vandervort  conference_room_large
# 5              6      Dr. Sydney Hackett PhD            normal_room
# 6              7           Mattye Kovacek MD            normal_room
# 7              8             Lawson Veum DVM  conference_room_large
# 8              9     Dr. Derrell Schneider V            double_room
# 9             10                Nathan Hyatt            deluxe_room
# 10            11         Miss Abbigail Kulas            double_room
# 11            12           Mrs. Etna Strosin            double_room
# 12            13                  Kelby Feil  conference_room_large
# ...

# %%
df_food_orders
# Out:
#        dest room bill room      date         time  #orders  menu id
# 0             L0        L0  16-02-09  10:15:00 AM        3        6
# 1     restaurant        L0  16-02-07  11:35:00 AM        5        8
# 2             L0        L0  16-03-17   6:54:00 AM        5       12
# 3     restaurant        L0  16-03-15   5:53:00 PM        4        7
# 4             L0        L0  16-03-16   2:54:00 PM        5        7
# 5     restaurant        L0  16-03-15   7:32:00 PM        1       11
# 6     restaurant        N1  16-03-16   7:52:00 AM        1        9
# 7             N2        N2  16-03-22  10:04:00 AM        2        8
# 8             L1        L1  16-02-08   1:17:00 PM        1        2
# 9            S61       S61  16-03-04  10:34:00 PM        3       10
# 10           S62       S62  16-03-05   1:36:00 AM        3       10
# 11    restaurant        L1  16-03-26   2:08:00 AM        4        0
# 12    restaurant        L2  16-03-24   4:01:00 PM        4        9
# ...

# %%
df_menu
# Out:
#     id                name  price         category
# 0    0               water    2.5            drink
# 1    1          soft-drink    3.0            drink
# 2    2                beer    3.5  alcoholic-drink
# 3    3                wine    3.5  alcoholic-drink
# 4    4    simple-breakfast    5.0        breakfast
# 5    5    french-breakfast    7.0        breakfast
# 6    6    deluxe-breakfast   12.0        breakfast
# 7    7        simple-lunch    5.0            lunch
# 8    8        deluxe-lunch   10.0            lunch
# 9    9      steak 'n stuff   18.0           dinner
# 10  10        surf 'n turf   17.0           dinner
# 11  11  vegetarian lasagna   16.0           dinner
# 12  12           spareribs   17.0           dinner
# 13  13          super soup   14.0           dinner
# 14  14              coffee    3.0            drink
# 15  15                 tea    2.5            drink
